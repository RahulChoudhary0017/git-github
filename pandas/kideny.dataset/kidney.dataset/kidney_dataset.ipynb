# %%
import pandas as pd

# %%
df = pd.read_csv("kidney_dataset.csv")
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df.head()
# Out:
#    Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                  54                     167                      1.023
# 1                  42                     127                      1.023
# 2                  38                     148                      1.016
# 3                   7                      98                      1.017
# 4                  67                     174                      1.015
#
#    Albumin in urine  Sugar in urine Red blood cells in urine  \
# 0                 1               4                   normal
# 1                 3               2                   normal
# 2                 0               0                 abnormal
# 3                 4               0                 abnormal
# 4                 1               1                   normal
#
#   Pus cells in urine Pus cell clumps in urine Bacteria in urine  \
# 0           abnormal              not present       not present
# ...

# %%
df.tail()
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
#        Albumin in urine  Sugar in urine Red blood cells in urine  \
# 20533                 5               3                   normal
# 20534                 3               4                   normal
# 20535                 3               5                 abnormal
# 20536                 1               5                 abnormal
# 20537                 4               5                 abnormal
#
#       Pus cells in urine Pus cell clumps in urine Bacteria in urine  \
# ...

# %%
df.head(9)
# Out:
#    Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                  54                     167                      1.023
# 1                  42                     127                      1.023
# 2                  38                     148                      1.016
# 3                   7                      98                      1.017
# 4                  67                     174                      1.015
# 5                  14                      92                      1.006
# 6                   9                     156                      1.010
# 7                  67                     100                      1.010
# 8                  42                     138                      1.017
#
#    Albumin in urine  Sugar in urine Red blood cells in urine  \
# 0                 1               4                   normal
# 1                 3               2                   normal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20538 entries, 0 to 20537
# Data columns (total 43 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Age of the patient                           20538 non-null  int64
#  1   Blood pressure (mm/Hg)                       20538 non-null  int64
#  2   Specific gravity of urine                    20538 non-null  float64
#  3   Albumin in urine                             20538 non-null  int64
#  4   Sugar in urine                               20538 non-null  int64
#  5   Red blood cells in urine                     20538 non-null  object
#  6   Pus cells in urine                           20538 non-null  object
#  7   Pus cell clumps in urine                     20538 non-null  object
#  8   Bacteria in urine                            20538 non-null  object
# ...

# %%
df.describe()
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# count        20538.000000            20538.000000               20538.000000
# mean            47.477895              130.352079                   1.015041
# std             24.941947               29.063838                   0.005793
# min              5.000000               80.000000                   1.005000
# 25%             26.000000              105.000000                   1.010000
# 50%             47.000000              131.000000                   1.015000
# 75%             69.000000              156.000000                   1.020000
# max             90.000000              180.000000                   1.025000
#
#        Albumin in urine  Sugar in urine  Random blood glucose level (mg/dl)  \
# count      20538.000000    20538.000000                        20538.000000
# mean           2.501266        2.494595                          284.630295
# ...

# %%
df.dtypes
# Out:
# Age of the patient                               int64
# Blood pressure (mm/Hg)                           int64
# Specific gravity of urine                      float64
# Albumin in urine                                 int64
# Sugar in urine                                   int64
# Red blood cells in urine                        object
# Pus cells in urine                              object
# Pus cell clumps in urine                        object
# Bacteria in urine                               object
# Random blood glucose level (mg/dl)               int64
# Blood urea (mg/dl)                             float64
# Serum creatinine (mg/dl)                       float64
# Sodium level (mEq/L)                           float64
# Potassium level (mEq/L)                        float64
# Hemoglobin level (gms)                         float64
# Packed cell volume (%)                           int64
# White blood cell count (cells/cumm)              int64
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20533    False
# 20534    False
# 20535    False
# 20536    False
# 20537    False
# Length: 20538, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                   False                   False                      False
# 1                   False                   False                      False
# 2                   False                   False                      False
# 3                   False                   False                      False
# 4                   False                   False                      False
# ...                   ...                     ...                        ...
# 20533               False                   False                      False
# 20534               False                   False                      False
# 20535               False                   False                      False
# 20536               False                   False                      False
# 20537               False                   False                      False
#
# ...

# %%
df.isnull().sum()
# Out:
# Age of the patient                             0
# Blood pressure (mm/Hg)                         0
# Specific gravity of urine                      0
# Albumin in urine                               0
# Sugar in urine                                 0
# Red blood cells in urine                       0
# Pus cells in urine                             0
# Pus cell clumps in urine                       0
# Bacteria in urine                              0
# Random blood glucose level (mg/dl)             0
# Blood urea (mg/dl)                             0
# Serum creatinine (mg/dl)                       0
# Sodium level (mEq/L)                           0
# Potassium level (mEq/L)                        0
# Hemoglobin level (gms)                         0
# Packed cell volume (%)                         0
# White blood cell count (cells/cumm)            0
# Red blood cell count (millions/cumm)           0
# Hypertension (yes/no)                          0
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Red blood cells in urine'].unique()
# Out:
# array(['normal', 'abnormal'], dtype=object)

# %%
rbc_dict={
    'normal': 0,
    'abnormal': 1,
}
df['Red blood cells in urine'] = df['Red blood cells in urine'].map(rbc_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Pus cells in urine'].unique()
# Out:
# array(['abnormal', 'normal'], dtype=object)

# %%
pus_dict={
    'normal': 0,
    'abnormal': 1,
}
df['Pus cells in urine'] = df['Pus cells in urine'].map(pus_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Pus cell clumps in urine'].unique()
# Out:
# array(['not present', 'present'], dtype=object)

# %%
pus_dict={
    'not present': 0,
    'present': 1,
}
df['Pus cell clumps in urine'] = df['Pus cell clumps in urine'].map(pus_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Bacteria in urine'].unique()
# Out:
# array(['not present', 'present'], dtype=object)

# %%
bac_dict={
    'not present': 0,
    'present': 1,
}
df['Bacteria in urine'] = df['Bacteria in urine'].map(bac_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Smoking status'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
smo_dict={
    'yes': 0,
    'no': 1,
}
df['Smoking status'] = df['Smoking status'].map(smo_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Physical activity level'].unique()
# Out:
# array(['low', 'moderate', 'high'], dtype=object)

# %%
pal_dict={
    'low': 0,
    'moderate': 1,
    'high': 2,
}
df['Physical activity level'] = df['Physical activity level'].map(pal_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df['Urinary sediment microscopy results'].unique()
# Out:
# array(['normal', 'abnormal'], dtype=object)

# %%
usmr_dict={
    'normal': 0,
    'abnormal': 1,
}
df['Urinary sediment microscopy results'] = df['Urinary sediment microscopy results'].map(usmr_dict)

# %%
df
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...

# %%
df.drop(['Target'] ,axis=1)
# Out:
#        Age of the patient  Blood pressure (mm/Hg)  Specific gravity of urine  \
# 0                      54                     167                      1.023
# 1                      42                     127                      1.023
# 2                      38                     148                      1.016
# 3                       7                      98                      1.017
# 4                      67                     174                      1.015
# ...                   ...                     ...                        ...
# 20533                  86                     113                      1.008
# 20534                  47                      80                      1.016
# 20535                  89                     178                      1.011
# 20536                  86                     138                      1.009
# 20537                  63                     120                      1.015
#
# ...
